# %% [markdown]
# # Variables & arithmetic
#
# _Extra practice · ungraded · CHEM 438_

# %% [markdown]
# <!-- c438-copy-note -->
# > ### ▶️ First — make your own copy
# > This notebook opened **read-only** (it comes straight from GitHub). To type your answers and keep your work:
# >
# > **File ▸ Save a copy in Drive**  —  or click **Copy to Drive** in the toolbar.
# >
# > Then work in *your* copy. It saves to your Google Drive automatically.

# %%
# Problem 1
# Assign the values 7 and 3 to variables `a` and `b`, respectively. Compute their sum and assign it to a variable `sum_ab` and print out `sub_ab`

# %%
# Problem 2
# Assign the values 15 and 4 to variables `x` and `y`, respectively. Compute their difference and assign it to a variable `diff_xy` and print out `diff_xy`

# %%
# Problem 3
# Assign the values 6 and 9 to variables `m` and `n`, respectively. Compute their product and assign it to a variable `prod_mn` and print out `prod_mn`

# %%
# Problem 4
# Assign the values 20 and 5 to variables `p` and `q`, respectively. Compute the quotient of `p` divided by `q` and assign it to a variable `quot_pq` and print out `quot_pq`

# %%
# Problem 5
# Assign the values 17 and 5 to variables `a` and `b`, respectively. Compute the remainder when `a` is divided by `b` and assign it to a variable `mod_ab` and print out `mod_ab`

# %%
# Problem 6
# Assign the values 8 and 2 to variables `base` and `exponent`, respectively. Compute the value of `base` raised to the power of `exponent` and assign it to a variable `power_be` and print out `power_be`

# %%
# Problem 7
# Assign the values 25 and 4 to variables `c` and `d`, respectively. Compute the floor division of `c` by `d` and assign it to a variable `floor_div_cd` and print out `floor_div_cd`

# %%
# Problem 8
# Assign the values 3 and 5 to variables `length` and `width`, respectively. Compute the area of a rectangle with these dimensions and assign it to a variable `area` and print out `area`

# %%
# Problem 9
# Assign the string "Hello" to variable `greeting` and "World" to variable `name`. Concatenate them with a space in between and assign the result to a variable `message` and print out `message`

# %%
# Problem 10
# Assign the string "Python" to variable `language`. Compute the length of the string and assign it to a variable `length` and print out `length`

# %%
# Problem 11
# Assign the string "Hello, World!" to variable `text`. Convert the string to all uppercase letters and assign it to a variable `uppercase_text` and print out `uppercase_text`

# %%
# Problem 12
# Assign the string "  Hello, World!  " to variable `text`. Remove the leading and trailing whitespace and assign the result to a variable `trimmed_text` and print out `trimmed_text`

# %%
# Problem 13
# Assign the values 12 and 4 to variables `a` and `b`, respectively. Compute their difference and assign it to a variable `diff_ab` and print out `diff_ab`

# %%
# Problem 14
# Assign the values 8 and 3 to variables `x` and `y`, respectively. Compute the floor division of `x` by `y` and assign it to a variable `floor_div_xy` and print out `floor_div_xy`

# %%
# Problem 15
# Assign the values 14 and 5 to variables `m` and `n`, respectively. Compute the remainder when `m` is divided by `n` and assign it to a variable `mod_mn` and print out `mod_mn`

# %%
# Problem 16
# Assign the value 16 to variable `base` and 0.5 to variable `exponent`. Compute the value of `base` raised to the power of `exponent` and assign it to a variable `power_be` and print out `power_be`

# %%
# Problem 17
# Assign the values 3.5 and 2.5 to variables `a` and `b`, respectively. Compute their sum and assign it to a variable `sum_ab` and print out `sum_ab`

# %%
# Problem 18
# Assign the float value 2.718 to variable `e` and the integer value 3 to variable `integer`. Compute the product of `e` and `integer` and assign it to a variable `product` and print out `product`

# %%
# Problem 19
# Assign the value 1.618 to variable `phi`. Compute the square of `phi` and assign it to a variable `square_phi` and print out `square_phi`

# %%
# Problem 20
# Assign the value 0 to variable `zero` and 1 to variable `one`. Add `zero` and `one` and assign the result to a variable `sum_zo` and print out `sum_zo`

# %%
# Problem 21
# Assign the string "Pi" to variable `pi_str` and the float value 3.14159 to variable `pi_val`. Concatenate `pi_str` with the string representation of `pi_val` and assign it to a variable `pi_message` and print out `pi_message`

# %%
# Problem 22
# Assign the string "E" to variable `e_str` and the float value 2.71828 to variable `e_val`. Concatenate `e_str` with the string representation of `e_val` and assign it to a variable `e_message` and print out `e_message`

# %%
# Problem 23
# Assign the value 50 to variable `num1` and 30 to variable `num2`. Compute their difference and assign it to a variable `diff` and print out `diff`

# %%
# Problem 24
# Assign the string "Good" to variable `first_word` and "Morning" to variable `second_word`. Concatenate them with a space in between and assign the result to a variable `greeting` and print out `greeting`

# %%
# Problem 25
# Assign the value 2.5 to variable `num`. Compute the square of `num` and assign it to a variable `square_num` and print out `square_num`

# %%
# Problem 26
# Assign the value 12.34 to variable `num`. Convert it to an integer and assign the result to a variable `int_num` and print out `int_num`

# %%
# Problem 27
# Assign the string “Goodbye” to variable farewell and “Everyone” to variable audience. Concatenate them with a space in between and assign the result to a variable `message` and print out `message`

# %%
# Problem 28
# Assign the value 18.75 to variable value. Convert it to an integer and assign the result to a variable `int_value` and print out `int_value`

# %%
# Problem 29
# Assign the string “Speed” to variable metric and the float value 3.6 to variable value. Concatenate metric with the string representation of value and assign it to a variable `message` and print out `message`

# %%
# Problem 30
# Assign the string "Python" to variable `language` and the string "Rocks!" to variable `statement`. Concatenate them and assign the result to a variable `full_statement` and print out `full_statement`

# %%
# Problem 31
# Assign the string "AI" to variable `topic` and the string "is awesome" to variable `description`. Concatenate them with a space and assign the result to a variable `statement` and print out `statement`

# %%
# Problem 32
# Assign the string "apple" to variable `fruit` and the string "pie" to variable `dessert`. Concatenate them with a space in between and assign the result to a variable `dish` and print out `dish`

# %%
# Problem 33
# Assign the string "My" to variable `word1`, the string "favorite" to variable `word2`, and the string "color" to variable `word3`. Concatenate them with spaces in between and assign the result to a variable `statement` and print out `statement`
