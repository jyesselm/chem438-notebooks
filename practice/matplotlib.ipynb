# %% [markdown]
# # Python Variable Assignment Problems

# %% [markdown]
# Problem 1
# Create a DataFrame with 'Month' and 'Sales' columns. Plot a line graph of sales over the months. make sure to include a title, x and y labels, and a legend.

# %%
data = {
    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],
    "Sales": [1000, 1200, 900, 1500, 1800, 1600],
}

# %% [markdown]
# Problem 2
# Create a DataFrame with 'Fruit' and 'Quantity' columns. Create a bar plot of quantities. include a title, x and y labels

# %%
data = {"Fruit": ["Apples", "Bananas", "Oranges", "Grapes"], "Quantity": [40, 55, 30, 25]}

# %% [markdown]
# Problem 3
# Create a DataFrame with 'Name' and 'Marks' columns. Create a horizontal bar plot of marks. include a title, x and y labels

# %%
data = {"Name": ["Anna", "Ben", "Chris", "Diana"], "Marks": [82, 74, 91, 68]}

# %% [markdown]
# Problem 4
# Create a DataFrame with 'Year' and 'Visitors' columns. Plot a line chart of visitors per year. include markers, a title, x and y labels

# %%
data = {"Year": [2015, 2016, 2017, 2018, 2019, 2020], "Visitors": [12000, 13500, 15000, 16000, 17500, 15500]}

# %% [markdown]
# Problem 5
# Create a DataFrame with 'Age' column. Create a histogram of ages with 8 bins. make sure to include a title, x and y labels

# %%
data = {
    "Age": [18, 22, 25, 29, 31, 35, 40, 45, 23, 27, 33, 38, 42, 50, 55, 60, 21, 26, 30, 34],
}

# %% [markdown]
# Problem 6
# Create a DataFrame with 'Month' and 'Temperature' columns. Create a line plot of average monthly temperatures with a red line and circle markers. include a title, x and y labels

# %%
data = {"Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"], "Temperature": [2, 5, 10, 15, 20, 25]}

# %% [markdown]
# Problem 7
# Create a DataFrame with 'Month', 'Product A', and 'Product B' columns. Plot both product sales on the same line chart with markers. make sure to include a title, x and y labels, and a legend

# %%
data = {
    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],
    "Product A": [120, 135, 150, 140, 160, 175],
    "Product B": [100, 115, 130, 125, 145, 155],
}

# %% [markdown]
# Problem 8
# Create a DataFrame with 'Category' and 'Amount' columns. Create a bar plot of amounts for each category. make sure to include a title, x and y labels

# %%
data = {
    "Category": ["Food", "Transport", "Utilities", "Entertainment", "Savings"],
    "Amount": [500, 300, 200, 150, 350],
}

# %% [markdown]
# Problem 9
# Create a DataFrame with 'Product' and 'Sales' columns. Create a pie chart showing the proportion of sales for each product.

# %%
data = {"Product": ["A", "B", "C", "D"], "Sales": [25, 30, 15, 30]}

# %% [markdown]
# Problem 10
# Create a DataFrame with 'Year' and 'Population' columns. Create a scatter plot of population growth over the years. make sure to include a title, x and y labels

# %%
data = {
    "Year": [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019],
    "Population": [8.5, 8.7, 8.9, 9.1, 9.3, 9.5, 9.7, 9.9, 10.1, 10.3],
}
df = pd.DataFrame(data)

# %% [markdown]
# Problem 11
# Create a DataFrame with 'Name' and 'Score' columns. Create a horizontal bar plot of scores for each person. make sure to include a title, x and y labels

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve"],
    "Score": [85, 92, 78, 95, 88],
}

# %% [markdown]
# Problem 12
# Create a line plot of monthly sales data with blue color and circular markers, add title "Monthly Sales Performance", label x-axis as "Month" and y-axis as "Sales ($)"

# %%
data = {
    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],
    "Sales": [10000, 11500, 12300, 11800, 13100, 14500],
}

# %% [markdown]
# Problem 13
# Create a scatter plot of student heights vs weights, color the points based on gender (blue for male, red for female), add a title "Student Height vs Weight", label axes, and include a legend

# %%
data = {
    "Height": [165, 170, 155, 172, 180, 160, 175, 158, 182, 168],
    "Weight": [60, 65, 55, 70, 80, 58, 72, 56, 85, 63],
    "Gender": ["F", "M", "F", "M", "M", "F", "M", "F", "M", "F"],
}

# %% [markdown]
# Problem 14
# Create a DataFrame with 'Month', 'Temperature', and 'Rainfall' columns. Create two subplots: a line plot of temperature (left) and a bar plot of rainfall (right). include titles and axis labels

# %%
data = {
    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],
    "Temperature": [2, 4, 8, 13, 18, 22],
    "Rainfall": [78, 65, 70, 55, 48, 40],
}

# %% [markdown]
# Problem 15<br>Create a DataFrame with 'Score' values. Make two subplots: a histogram of raw scores (left) and a bar plot of counts per grade bucket (right) with buckets F(<60), D(60–69), C(70–79), B(80–89),<br>A(90–100). include titles and axis labels

# %%
data = {
    "Score": [55, 62, 77, 83, 91, 68, 74, 88, 95, 100, 59, 72, 81, 86, 93, 65, 70, 79, 84, 90],
}
