# %% [markdown]
# # Python Variable Assignment Problems

# %% [markdown]
# Problem 1
# Create an RDKit molecule object for aspirin (acetylsalicylic acid) using its SMILES string. Generate a 3D depiction of the molecule and display it.

# %% [markdown]
# Problem 2
# Generate a 3D depiction of caffeine and display it with a space-filling mode Use the SMILES string "CN1C=NC2=C1C(=O)N(C(=O)N2C)C" for caffeine.

# %% [markdown]
# Problem 3
# Create a 3D depiction of ibuprofen and highlight its aromatic rings. Use the SMILES string "CC(C)Cc1ccc(cc1)[C@H](C)C(=O)O" for ibuprofen.

# %% [markdown]
# Problem 4
# Question 4: Create a 3D depiction of aspirin and highlight its functional groups as spheres (carboxylic acid and ester), Use the SMILES string "CC(=O)OC1=CC=CC=C1C(=O)O" for aspirin.

# %% [markdown]
# Problem 5
# Load and display the 3D structure of hemoglobin (PDB ID: 1GZX) using py3Dmol. color each chain a different color and render as a cartoon

# %% [markdown]
# Problem 6
# Load the structure of the SARS-CoV-2 main protease (PDB ID: 6LU7) and display it in surface representation. Use a white color for the surface and set the opacity to 0.5.

# %% [markdown]
# Problem 7<br>Create a viewer in Jupyter notebook to display protein structure 1AQ1 from PDB, color it based on secondary structure (helix=red, sheet=yellow, other=white), {'ss':'h'} is for helix and {'ss':'s'} is<br>for sheet, and add a surface representation with 50% transparency

# %% [markdown]
# Problem 8
# Load the structure of the SARS-CoV-2 main protease (PDB ID: 6LU7) and display it in cartoon representation. Color the protein lightblue and show the ligand as sticks with red carbon atoms.

# %% [markdown]
# Problem 9
# Load the 3D structure of lysozyme (PDB ID: 1AKI) using BioPandas, Display the first five residues of chain A, showing their residue name, residue number, and atom coordinates.

# %% [markdown]
# Problem 10
# Question Using BioPandas, load the PDB structure 2PTC (trypsin-inhibitor complex) and compute the distance between the CA atom of residue 195 in chain E and residue 14 in chain I.

# %% [markdown]
# Problem 11
# Load hemoglobin (PDB ID: 1GZX) using BioPandas. Calculate the number of unique residues in each chain.

# %% [markdown]
# Problem 12
# Load a protein using BioPandas (PDB ID: 1CRN) and extract only alpha carbon (CA) coordinates. Then plot x, y, z coordinates of CA atoms in a 3D plot.

# %% [markdown]
# Problem 13
# Using py3Dmol, load the protein 1CRN and color the backbone by chain (A in blue, B in red if present). Display it in cartoon mode.

# %% [markdown]
# Problem 14
# Load the structure of Green Fluorescent Protein (PDB ID: 1EMA) in py3Dmol. Show the structure in cartoon representation and highlight the chromophore (residues 65–67) in red sticks.

# %% [markdown]
# Problem 15
# Using BioPandas, load the 1GZX structure and filter all atoms within 5 Å of the heme group (residue HEM). Display their residue names and distances.

# %% [markdown]
# Problem 16
# Load the enzyme ribonuclease (PDB ID: 7RSA) using BioPandas. Find the residue with the highest average atomic B-factor (temperature factor).
